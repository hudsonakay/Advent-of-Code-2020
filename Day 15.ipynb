# %%
import pandas as pd
import numpy as np

# %%
# 2,0,6,12,1,3

# %%
numbers_spoken = [2,0,6,12,1,3]
for turn in range(6,2030):
    rev = numbers_spoken.copy()
    rev.reverse()
    if numbers_spoken[-1] not in numbers_spoken[:-1]:
        numbers_spoken.append(0)
    else:
        last = turn
        second_last = rev[1:].index(numbers_spoken[-1])
        numbers_spoken.append(second_last+1)
numbers_spoken[2019]
# Out:
# 1428

# %%
numbers_spoken = [2,0,6,12,1,3]
for turn in range(6,10000):
    rev = numbers_spoken.copy()
    rev.reverse()
    if numbers_spoken[-1] not in numbers_spoken[:-1]:
        numbers_spoken.append(0)
    else:
        last = turn
        second_last = rev[1:].index(numbers_spoken[-1])
        numbers_spoken.append(second_last+1)
# numbers_spoken[29999999]

# %%
numbers_spoken
# Out:
# [2,
#  0,
#  6,
#  12,
#  1,
#  3,
#  0,
#  5,
#  0,
#  2,
#  9,
#  0,
#  3,
#  7,
#  0,
#  3,
#  3,
#  1,
#  13,
#  0,
#  5,
#  13,
#  3,
#  6,
#  21,
#  0,
#  6,
#  3,
#  5,
#  8,
#  0,
#  5,
#  3,
#  5,
#  2,
#  25,
#  0,
#  6,
#  11,
#  0,
#  3,
#  8,
#  12,
#  39,
#  0,
#  5,
#  12,
#  4,
#  0,
#  4,
#  2,
#  16,
#  0,
#  4,
#  4,
#  1,
#  38,
#  0,
#  5,
#  13,
#  38,
#  4,
#  7,
#  49,
#  0,
#  7,
#  3,
#  26,
#  0,
#  4,
#  8,
#  29,
#  0,
#  4,
#  4,
#  1,
#  20,
#  0,
#  5,
#  20,
#  3,
#  14,
#  0,
#  5,
#  5,
#  1,
#  10,
#  0,
#  5,
#  4,
#  15,
#  0,
#  4,
#  3,
#  13,
#  35,
#  0,
#  5,
#  9,
#  88,
#  0,
#  4,
#  9,
#  4,
#  2,
#  54,
#  0,
#  6,
#  70,
#  0,
#  3,
#  17,
#  0,
#  3,
#  3,
#  1,
#  30,
#  0,
#  5,
#  21,
#  95,
#  0,
#  4,
#  19,
#  0,
#  3,
#  11,
#  88,
#  28,
#  0,
#  5,
#  12,
#  85,
#  0,
#  4,
#  12,
#  4,
#  2,
#  33,
#  0,
#  6,
#  33,
#  3,
#  17,
#  32,
#  0,
#  6,
#  6,
#  1,
#  33,
#  8,
#  80,
#  0,
#  7,
#  88,
#  27,
#  0,
#  4,
#  21,
# ...

# %%
start = len(numbers_spoken)
for turn in range(start,100000):
    rev = numbers_spoken.copy()
    rev.reverse()
    if numbers_spoken[-1] not in numbers_spoken[:-1]:
        numbers_spoken.append(0)
    else:
        last = turn
        second_last = rev[1:].index(numbers_spoken[-1])
        numbers_spoken.append(second_last+1)

# %%
start = len(numbers_spoken)
for turn in range(start,1000000):
    rev = numbers_spoken.copy()
    rev.reverse()
    if numbers_spoken[-1] not in numbers_spoken[:-1]:
        numbers_spoken.append(0)
    else:
        last = turn
        second_last = rev[1:].index(numbers_spoken[-1])
        numbers_spoken.append(second_last+1)

# %%
start = len(numbers_spoken)
for turn in range(start,10000000):
    rev = numbers_spoken.copy()
    rev.reverse()
    if numbers_spoken[-1] not in numbers_spoken[:-1]:
        numbers_spoken.append(0)
    else:
        last = turn
        second_last = rev[1:].index(numbers_spoken[-1])
        numbers_spoken.append(second_last+1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-01287c19b9b0> in <module>
#       1 start = len(numbers_spoken)
#       2 for turn in range(start,10000000):
# ----> 3     rev = numbers_spoken.copy()
#       4     rev.reverse()
#       5     if numbers_spoken[-1] not in numbers_spoken[:-1]:
#
# KeyboardInterrupt:

# %%
numbers_spoken = [2,0,6,12,1,3]
for turn in range(6,30000010):
#     rev = numbers_spoken.copy()
#     rev.reverse()
    if numbers_spoken[-1] not in numbers_spoken[:-1]:
        numbers_spoken.append(0)
    else:
#         last = turn
        second_last = numbers_spoken[-2::-1].index(numbers_spoken[-1])
        numbers_spoken.append(second_last+1)
    if turn%1000000 == 0:
        print(len(numbers_spoken))
# Out:
# 1000001
# 2000001
# 3000001
# 4000001
# 5000001
# 6000001
# 7000001
# 8000001
# 9000001
# 10000001
# 11000001
# 12000001
# 13000001
# 14000001
# 15000001

# %%
len(numbers_spoken)
# Out:
# 3167919

# %%
len(numbers_spoken)
# Out:
# 3300776
